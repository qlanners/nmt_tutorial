# %%
import unicodedata
import re
import math
import psutil
import time
import datetime
from io import open
import random
from random import shuffle
import argparse
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import torch.cuda

"""this line clears sys to allow for argparse to work as gradient clipper"""
import sys; sys.argv=['']; del sys

# %%
use_cuda = torch.cuda.is_available()
print(use_cuda)
# Out:
# True

# %%
"""This function converts a Unicode string to plain ASCII 
from https://stackoverflow.com/a/518232/2809427"""
def uniToAscii(sentence):
    return ''.join(
        c for c in unicodedata.normalize('NFD', sentence)
        if unicodedata.category(c) != 'Mn'
    )


"""Lowercase, trim, and remove non-letter characters (from pytorch)"""
def normalizeString(s):
    s = re.sub(r" ##AT##-##AT## ", r" ", s)
    s = uniToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s   

  
"""Denote patterns that sentences must start with to be kept in dataset. 
Can be changed if desired (from pytorch)"""
eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)



"""Filters each input-output pair, keeping sentences that are less than max_length 
if start_filter is true, also filters out sentences that don't start with eng_prefixes"""
def filterPair(p, max_length, start_filter):
    filtered = len(p[0].split(' ')) < max_length and \
        len(p[1].split(' ')) < max_length 
    if start_filter:
        return filtered and p[1].startswith(eng_prefixes)
    else:
        return filtered

"""Filters all of the input-output language pairs in the dataset using filterPair 
for each pair (from pytorch)"""
def filterPairs(pairs, max_length, start_filter):
    return [pair for pair in pairs if filterPair(pair, max_length, start_filter)]

# %%
"""start of sentence tag"""
SOS_token = 0

"""end of sentence tag"""
EOS_token = 1

"""unknown word tag (this is used to handle words that are not in our Vocabulary)"""
UNK_token = 2


"""Lang class, used to store the vocabulary of each language"""
class Lang:
    def __init__(self, language):
        self.language_name = language
        self.word_to_index = {"SOS":SOS_token, "EOS":EOS_token, "<UNK>":UNK_token}
        self.word_to_count = {}
        self.index_to_word = {SOS_token: "SOS", EOS_token: "EOS", UNK_token: "<UNK>"}
        self.vocab_size = 3
        self.cutoff_point = -1


    def countSentence(self, sentence):
        for word in sentence.split(' '):
            self.countWords(word)

    """counts the number of times each word appears in the dataset"""
    def countWords(self, word):
        if word not in self.word_to_count:
            self.word_to_count[word] = 1
        else:
            self.word_to_count[word] += 1

    """if the number of unique words in the dataset is larger than the
    specified max_vocab_size, creates a cutoff point that is used to
    leave infrequent words out of the vocabulary"""
    def createCutoff(self, max_vocab_size):
        word_freqs = list(self.word_to_count.values())
        word_freqs.sort(reverse=True)
        if len(word_freqs) > max_vocab_size:
            self.cutoff_point = word_freqs[max_vocab_size]

    """assigns each unique word in a sentence a unique index"""
    def addSentence(self, sentence):
        new_sentence = ''
        for word in sentence.split(' '):
            unk_word = self.addWord(word)
            if not new_sentence:
                new_sentence =unk_word
            else:
                new_sentence = new_sentence + ' ' + unk_word
        return new_sentence

    """assigns a word a unique index if not already in vocabulary
    and it appeaars often enough in the dataset
    (self.word_to_count is larger than self.cutoff_point)"""
    def addWord(self, word):
        if self.word_to_count[word] > self.cutoff_point:
            if word not in self.word_to_index:
                self.word_to_index[word] = self.vocab_size
                self.index_to_word[self.vocab_size] = word
                self.vocab_size += 1
            return word
        else:
            return self.index_to_word[2]

# %%
'''prepares both the input and output Lang classes from the passed dataset'''

def prepareLangs(lang1, lang2, file_path, reverse=False):
    print("Reading lines...")

    if len(file_path) == 2:
        lang1_lines = open(file_path[0], encoding='utf-8').\
            read().strip().split('\n')

        lang2_lines = open(file_path[1], encoding='utf-8').\
            read().strip().split('\n')

        if len(lang1_lines) != len(lang2_lines):
            print("Input and output text sizes do not align")
            print("Number of lang1 lines: %s " %len(lang1_lines))
            print("Number of lang2 lines: %s " %len(lang2_lines))
            quit()

        pairs = []

        for line in range(len(lang1_lines)):
            pairs.append([normalizeString(lang1_lines[line]),
                          normalizeString(lang2_lines[line])])            


    elif len(file_path) == 1:
        lines = open(file_path[0], encoding='utf-8').\
    	read().strip().split('\n')
        pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
"""completely prepares both input and output languages 
and returns cleaned and trimmed train and test pairs"""

def prepareData(lang1, lang2, file_path, max_vocab_size=50000, 
                reverse=False, trim=0, start_filter=False, perc_train_set=0.9, 
                print_to=None):
    
    input_lang, output_lang, pairs = prepareLangs(lang1, lang2, 
                                                  file_path, reverse)
    
    print("Read %s sentence pairs" % len(pairs))
    
    if print_to:
        with open(print_to,'a') as f:
            f.write("Read %s sentence pairs \n" % len(pairs))
    
    if trim != 0:
        pairs = filterPairs(pairs, trim, start_filter)
        print("Trimmed to %s sentence pairs" % len(pairs))
        if print_to:
            with open(print_to,'a') as f:
                f.write("Read %s sentence pairs \n" % len(pairs))

    print("Counting words...")
    for pair in pairs:
        input_lang.countSentence(pair[0])
        output_lang.countSentence(pair[1])


    input_lang.createCutoff(max_vocab_size)
    output_lang.createCutoff(max_vocab_size)

    pairs = [(input_lang.addSentence(pair[0]),output_lang.addSentence(pair[1])) 
             for pair in pairs]

    shuffle(pairs)
    
    train_pairs = pairs[:math.ceil(perc_train_set*len(pairs))]
    test_pairs = pairs[math.ceil(perc_train_set*len(pairs)):]

    print("Train pairs: %s" % (len(train_pairs)))
    print("Test pairs: %s" % (len(test_pairs)))
    print("Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):")
    print("%s, %s -> %s" % (input_lang.language_name, len(input_lang.word_to_count),
                            input_lang.vocab_size,))
    print("%s, %s -> %s" % (output_lang.language_name, len(output_lang.word_to_count), 
                            output_lang.vocab_size))
    print()

    if print_to:
        with open(print_to,'a') as f:
            f.write("Train pairs: %s" % (len(train_pairs)))
            f.write("Test pairs: %s" % (len(test_pairs)))
            f.write("Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):")
            f.write("%s, %s -> %s" % (input_lang.language_name, 
                                      len(input_lang.word_to_count),
                                      input_lang.vocab_size,))
            f.write("%s, %s -> %s \n" % (output_lang.language_name, len(output_lang.word_to_count), 
                            output_lang.vocab_size))
        
    return input_lang, output_lang, train_pairs, test_pairs

# %%
"""converts a sentence to one hot encoding vectors - pytorch allows us to just
use the number corresponding to the unique index for that word,
rather than a complete one hot encoding vector for each word"""
def indexesFromSentence(lang, sentence):
    indexes = []
    for word in sentence.split(' '):
        try:
            indexes.append(lang.word_to_index[word])
        except:
            indexes.append(lang.word_to_index["<UNK>"])
    return indexes


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    result = torch.LongTensor(indexes).view(-1)
    if use_cuda:
        return result.cuda()
    else:
        return result
      
"""converts a pair of sentence (input and target) to a pair of tensors"""
def tensorsFromPair(input_lang, output_lang, pair):
    input_variable = tensorFromSentence(input_lang, pair[0])
    target_variable = tensorFromSentence(output_lang, pair[1])
    return (input_variable, target_variable)
  

"""converts from tensor of one hot encoding vector indices to sentence"""
def sentenceFromTensor(lang, tensor):
    raw = tensor.data
    words = []
    for num in raw:
        words.append(lang.index_to_word[num.item()])
    return ' '.join(words)

# %%
"""seperates data into batches of size batch_size"""
def batchify(data, input_lang, output_lang, batch_size, shuffle_data=True):
    if shuffle_data == True:
        shuffle(data)
    number_of_batches = len(data) // batch_size
    batches = list(range(number_of_batches))
    longest_elements = list(range(number_of_batches))
    
    for batch_number in range(number_of_batches):
        longest_input = 0
        longest_target = 0
        input_variables = list(range(batch_size))
        target_variables = list(range(batch_size))
        index = 0      
        for pair in range((batch_number*batch_size),((batch_number+1)*batch_size)):
            input_variables[index], target_variables[index] = tensorsFromPair(input_lang, output_lang, data[pair])
            if len(input_variables[index]) >= longest_input:
                longest_input = len(input_variables[index])
            if len(target_variables[index]) >= longest_target:
                longest_target = len(target_variables[index])
            index += 1
        batches[batch_number] = (input_variables, target_variables)
        longest_elements[batch_number] = (longest_input, longest_target)
    return batches , longest_elements, number_of_batches


"""pads batches to allow for sentences of variable lengths to be computed in parallel"""
def pad_batch(batch):
    padded_inputs = torch.nn.utils.rnn.pad_sequence(batch[0],padding_value=EOS_token)
    padded_targets = torch.nn.utils.rnn.pad_sequence(batch[1],padding_value=EOS_token)
    return (padded_inputs, padded_targets)

# %%
class EncoderRNN(nn.Module):
	def __init__(self,input_size,hidden_size,layers=1,dropout=0.1,
               bidirectional=True):
		super(EncoderRNN, self).__init__()

		if bidirectional:
			self.directions = 2
		else:
			self.directions = 1
		self.input_size = input_size
		self.hidden_size = hidden_size
		self.num_layers = layers
		self.dropout = dropout
		self.embedder = nn.Embedding(input_size,hidden_size)
		self.dropout = nn.Dropout(dropout)
		self.lstm = nn.LSTM(input_size=hidden_size,hidden_size=hidden_size,
                        num_layers=layers,dropout=dropout,
                        bidirectional=bidirectional,batch_first=False)
		self.fc = nn.Linear(hidden_size*self.directions, hidden_size)

	def forward(self, input_data, h_hidden, c_hidden):
		embedded_data = self.embedder(input_data)
		embedded_data = self.dropout(embedded_data)
		hiddens, outputs = self.lstm(embedded_data, (h_hidden, c_hidden))

		return hiddens, outputs

	"""creates initial hidden states for encoder corresponding to batch size"""
	def create_init_hiddens(self, batch_size):
		h_hidden = Variable(torch.zeros(self.num_layers*self.directions, 
                                    batch_size, self.hidden_size))
		c_hidden = Variable(torch.zeros(self.num_layers*self.directions, 
                                    batch_size, self.hidden_size))
		if torch.cuda.is_available():
			return h_hidden.cuda(), c_hidden.cuda()
		else:
			return h_hidden, c_hidden

# %%
class DecoderAttn(nn.Module):
	def __init__(self, hidden_size, output_size, layers=1, dropout=0.1, bidirectional=True):
		super(DecoderAttn, self).__init__()

		if bidirectional:
			self.directions = 2
		else:
			self.directions = 1
		self.output_size = output_size
		self.hidden_size = hidden_size
		self.num_layers = layers
		self.dropout = dropout
		self.embedder = nn.Embedding(output_size,hidden_size)
		self.dropout = nn.Dropout(dropout)
		self.score_learner = nn.Linear(hidden_size*self.directions, 
                                   hidden_size*self.directions)
		self.lstm = nn.LSTM(input_size=hidden_size,hidden_size=hidden_size,
                        num_layers=layers,dropout=dropout,
                        bidirectional=bidirectional,batch_first=False)
		self.context_combiner = nn.Linear((hidden_size*self.directions)
                                      +(hidden_size*self.directions), hidden_size)
		self.tanh = nn.Tanh()
		self.output = nn.Linear(hidden_size, output_size)
		self.soft = nn.Softmax(dim=1)
		self.log_soft = nn.LogSoftmax(dim=1)


	def forward(self, input_data, h_hidden, c_hidden, encoder_hiddens):

		embedded_data = self.embedder(input_data)
		embedded_data = self.dropout(embedded_data)	
		batch_size = embedded_data.shape[1]
		hiddens, outputs = self.lstm(embedded_data, (h_hidden, c_hidden))	
		top_hidden = outputs[0].view(self.num_layers,self.directions,
                                 hiddens.shape[1],
                                 self.hidden_size)[self.num_layers-1]
		top_hidden = top_hidden.permute(1,2,0).contiguous().view(batch_size,-1, 1)

		prep_scores = self.score_learner(encoder_hiddens.permute(1,0,2))
		scores = torch.bmm(prep_scores, top_hidden)
		attn_scores = self.soft(scores)
		con_mat = torch.bmm(encoder_hiddens.permute(1,2,0),attn_scores)
		h_tilde = self.tanh(self.context_combiner(torch.cat((con_mat,
                                                         top_hidden),dim=1)
                                              .view(batch_size,-1)))
		pred = self.output(h_tilde)
		pred = self.log_soft(pred)

		
		return pred, outputs

# %%
'''Performs training on a single batch of training data. Computing the loss 
according to the passed loss_criterion and back-propagating on this loss.'''

def train_batch(input_batch, target_batch, encoder, decoder, 
                encoder_optimizer, decoder_optimizer, loss_criterion):
	encoder_optimizer.zero_grad()
	decoder_optimizer.zero_grad()
	loss = 0
	enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(input_batch.shape[1])

	enc_hiddens, enc_outputs = encoder(input_batch, enc_h_hidden, enc_c_hidden)

	decoder_input = Variable(torch.LongTensor(1,input_batch.shape[1]).
                           fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
					else Variable(torch.LongTensor(1,input_batch.shape[1]).
                        fill_(output_lang.word_to_index.get("SOS")))

	dec_h_hidden = enc_outputs[0]
	dec_c_hidden = enc_outputs[1]
	
	for i in range(target_batch.shape[0]):
		pred, dec_outputs = decoder(decoder_input, dec_h_hidden, 
                                dec_c_hidden, enc_hiddens)

		decoder_input = target_batch[i].view(1,-1)
		dec_h_hidden = dec_outputs[0]
		dec_c_hidden = dec_outputs[1]
		
		loss += loss_criterion(pred,target_batch[i])


	loss.backward()

	torch.nn.utils.clip_grad_norm_(encoder.parameters(),args.clip)
	torch.nn.utils.clip_grad_norm_(decoder.parameters(),args.clip)

	encoder_optimizer.step()
	decoder_optimizer.step()

	return loss.item() / target_batch.shape[0]

# %%
'''Performs a complete epoch of training through all of the training_batches'''

def train(train_batches, encoder, decoder, encoder_optimizer, decoder_optimizer, loss_criterion):

	round_loss = 0
	i = 1
	for batch in train_batches:
		i += 1
		(input_batch, target_batch) = pad_batch(batch)
		batch_loss = train_batch(input_batch, target_batch, encoder, decoder, encoder_optimizer, decoder_optimizer, loss_criterion)
		round_loss += batch_loss

	return round_loss / len(train_batches)

# %%
'''Evaluates the loss on a single batch of test data. Computing the loss 
according to the passed loss_criterion. Does not perform back-prop'''

def test_batch(input_batch, target_batch, encoder, decoder, loss_criterion):
	
	loss = 0

	#create initial hidde state for encoder
	enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(input_batch.shape[1])

	enc_hiddens, enc_outputs = encoder(input_batch, enc_h_hidden, enc_c_hidden)

	decoder_input = Variable(torch.LongTensor(1,input_batch.shape[1]).
                           fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
					else Variable(torch.LongTensor(1,input_batch.shape[1]).
                        fill_(output_lang.word_to_index.get("SOS")))
	dec_h_hidden = enc_outputs[0]
	dec_c_hidden = enc_outputs[1]
	
	for i in range(target_batch.shape[0]):
		pred, dec_outputs = decoder(decoder_input, dec_h_hidden, dec_c_hidden, enc_hiddens)

		topv, topi = pred.topk(1,dim=1)
		ni = topi.view(1,-1)
		
		decoder_input = ni
		dec_h_hidden = dec_outputs[0]
		dec_c_hidden = dec_outputs[1]

		loss += loss_criterion(pred,target_batch[i])
		
	return loss.item() / target_batch.shape[0]

# %%
'''Computes the loss value over all of the test_batches'''

def test(test_batches, encoder, decoder, loss_criterion):

	with torch.no_grad():
		test_loss = 0

		for batch in test_batches:
			(input_batch, target_batch) = pad_batch(batch)
			batch_loss = test_batch(input_batch, target_batch, encoder, decoder, loss_criterion)
			test_loss += batch_loss

	return test_loss / len(test_batches)

# %%
'''Returns the predicted translation of a given input sentence. Predicted
translation is trimmed to length of cutoff_length argument'''

def evaluate(encoder, decoder, sentence, cutoff_length):
	with torch.no_grad():
		input_variable = tensorFromSentence(input_lang, sentence)
		input_variable = input_variable.view(-1,1)
		enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(1)

		enc_hiddens, enc_outputs = encoder(input_variable, enc_h_hidden, enc_c_hidden)

		decoder_input = Variable(torch.LongTensor(1,1).fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
						else Variable(torch.LongTensor(1,1).fill_(output_lang.word_to_index.get("SOS")))
		dec_h_hidden = enc_outputs[0]
		dec_c_hidden = enc_outputs[1]

		decoded_words = []

		for di in range(cutoff_length):
			pred, dec_outputs = decoder(decoder_input, dec_h_hidden, dec_c_hidden, enc_hiddens)

			topv, topi = pred.topk(1,dim=1)
			ni = topi.item()
			if ni == output_lang.word_to_index.get("EOS"):
				decoded_words.append('<EOS>')
				break
			else:
				decoded_words.append(output_lang.index_to_word[ni])

			decoder_input = Variable(torch.LongTensor(1,1).fill_(ni).cuda()) if use_cuda \
							else Variable(torch.LongTensor(1,1).fill_(ni))
			dec_h_hidden = dec_outputs[0]
			dec_c_hidden = dec_outputs[1]

		output_sentence = ' '.join(decoded_words)
    
		return output_sentence

# %%
'''Evaluates prediction translations for a specified number (n) of sentences
chosen randomly from a list of passed sentence pairs. Returns three sentences
in the format:
                  > input sentence
                  = correct translation
                  < predicted translation'''

def evaluate_randomly(encoder, decoder, pairs, n=2, trim=100):
	for i in range(n):
		pair = random.choice(pairs)
		print('>', pair[0])
		print('=', pair[1])
		output_sentence = evaluate(encoder, decoder, pair[0],cutoff_length=trim)
		print('<', output_sentence)
		print('')    
		if create_txt:
			f = open(print_to, 'a')
			f.write("\n \
				> %s \n \
				= %s \n \
				< %s \n" % (pair[0], pair[1], output_sentence))
			f.close()

# %%
'''Used to plot the progress of training. Plots the loss value vs. time'''
def showPlot(times, losses, fig_name):
    x_axis_label = 'Minutes'
    colors = ('red','blue')
    if max(times) >= 120:
    	times = [mins/60 for mins in times]
    	x_axis_label = 'Hours'
    i = 0
    for key, losses in losses.items():
    	if len(losses) > 0:
    		plt.plot(times, losses, label=key, color=colors[i])
    		i += 1
    plt.legend(loc='upper left')
    plt.xlabel(x_axis_label)
    plt.ylabel('Loss')
    plt.title('Training Results')
    plt.savefig(fig_name+'.png')
    plt.close('all')
    
'''prints the current memory consumption'''
def mem():
	if use_cuda:
		mem = torch.cuda.memory_allocated()/1e7
	else:
		mem = psutil.cpu_percent()
	print('Current mem usage:')
	print(mem)
	return "Current mem usage: %s \n" % (mem)

'''converts a time measurement in seconds to hours'''
def asHours(s):
	m = math.floor(s / 60)
	h = math.floor(m / 60)
	s -= m * 60
	m -= h * 60
	return '%dh %dm %ds' % (h, m, s)

# %%
'''The master function that trains the model. Evlautes progress on the train set
(if present) and also records the progress of training in both a txt file and
a png graph. Also can save the weights of both the Encoder and Decoder 
for future use.'''

def train_and_test(epochs, test_eval_every, plot_every, learning_rate, 
                   lr_schedule, train_pairs, test_pairs, input_lang, 
                   output_lang, batch_size, test_batch_size, encoder, decoder, 
                   loss_criterion, trim, save_weights):
	
	times = []
	losses = {'train set':[], 'test set': []}

	test_batches, longest_seq, n_o_b = batchify(test_pairs, input_lang, 
                                              output_lang, test_batch_size, 
                                              shuffle_data=False)

	start = time.time()
	for i in range(1,epochs+1):
    
		'''adjust the learning rate according to the learning rate schedule
		specified in lr_schedule'''
		if i in lr_schedule.keys():
			learning_rate /= lr_schedule.get(i)


		encoder.train()
		decoder.train()

		encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
		decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)

		batches, longest_seq, n_o_b = batchify(train_pairs, input_lang, 
                                           output_lang, batch_size, 
                                           shuffle_data=True)
		train_loss = train(batches, encoder, decoder, encoder_optimizer, 
                       decoder_optimizer, loss_criterion)
		
		now = time.time()
		print("Iter: %s \nLearning Rate: %s \nTime: %s \nTrain Loss: %s \n" 
          % (i, learning_rate, asHours(now-start), train_loss))

		if create_txt:
			with open(print_to, 'a') as f:
				f.write("Iter: %s \nLeaning Rate: %s \nTime: %s \nTrain Loss: %s \n" \
					% (i, learning_rate, asHours(now-start), train_loss))

		if i % test_eval_every == 0:
			if test_pairs:
				test_loss = test(test_batches, encoder, decoder, criterion)
				print("Test set loss: %s" % (test_loss))
				if create_txt:
					with open(print_to, 'a') as f:
						f.write("Test Loss: %s \n" % (test_loss))
				evaluate_randomly(encoder, decoder, test_pairs, trim)
			else:
				evaluate_randomly(encoder, decoder, train_pairs, trim)

		if i % plot_every == 0:
			times.append((time.time()-start)/60)
			losses['train set'].append(train_loss)
			if test_pairs:
				losses['test set'].append(test_loss)
			showPlot(times, losses, output_file_name)
			if save_weights:
				torch.save(encoder.state_dict(), output_file_name+'_enc_weights.pt')
				torch.save(decoder.state_dict(), output_file_name+'_dec_weights.pt')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-52693f5c-d490-4db9-a31a-ebc3c13092f3" name="files[]" multiple disabled />
#      <output id="result-52693f5c-d490-4db9-a31a-ebc3c13092f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving eng-fra.txt to eng-fra (1).txt

# %%
ls
# Out:
# 'eng-fra (1).txt'
#  eng-fra.txt
#  sample_data/
#  testdata.orig_trim.10_vocab.20000_directions.2_layers.2_hidden.440_dropout.0.2_learningrate.1_batch.32_epochs.100.png
#  testdata.orig_trim.10_vocab.20000_directions.2_layers.2_hidden.440_dropout.0.2_learningrate.1_batch.32_epochs.100.txt

# %%
"""PROVIDE INFORMATION ON THE DATASET AND DATASET CLEANING"""

input_lang_name = 'fre'
output_lang_name = 'en'

"""name of your dataset"""
dataset = 'orig'

"""file path of dataset in the form of a tuple. If translated sentences are
stored in two files, this tuple will have two elements"""
raw_data_file_path = ('eng-fra.txt',)

"""True if you want to reverse the order of the sentence pairs. For example, 
in our dataset the sentence pairs list the English sentence first followed by
the French translation. But we want to translate from French to English,
so we set reverse as True."""
reverse=True

"""Remove sentences from dataset that are longer than trim (in either language)"""
trim = 10

"""max number of words in the vocabulary for both languages"""
max_vocab_size= 20000

"""if true removes sentences from the dataset that don't start with eng_prefixes.
Typically will want to use False, but implemented to compare results with Pytorch
tutorial. Can also change the eng_prefixes to prefixes of other languages or
other English prefixes. Just be sure that the prefixes apply to the OUTPUT
language (i.e. the language that the model is translating to NOT from)"""
start_filter = True

"""denotes what percentage of the data to use as training data. the remaining 
percentage becomes test data. Typically want to use 0.8-0.9. 1.0 used here to 
compare with PyTorch results where no test set was utilized"""
perc_train_set = 1.0

# %%
"""OUTPUT OPTIONS"""

"""denotes how often to evaluate a loss on the test set and print
sample predictions on the test set.
if no test set, simply prints sample predictions on the train set."""
test_eval_every = 1

"""denotes how often to plot the loss values of train and test (if applicable)"""
plot_every = 1

"""if true creates a txt file of the output"""
create_txt = True

"""if true saves the encoder and decoder weights to seperate .pt files for later use"""
save_weights = False

# %%
"""HYPERPARAMETERS: FEEL FREE TO PLAY WITH THESE TO TRY TO ACHIEVE BETTER RESULTS"""

"""signifies whether the Encoder and Decoder should be bidirectional LSTMs or not"""
bidirectional = True
if bidirectional:
	directions = 2
else:
	directions = 1

"""number of layers in both the Encoder and Decoder"""
layers = 2

"""Hidden size of the Encoder and Decoder"""
hidden_size = 440

"""Dropout value for Encoder and Decoder"""
dropout = 0.2

"""Training set batch size"""
batch_size = 32

"""Test set batch size"""
test_batch_size = 32

"""number of epochs (full passes through the training data)"""
epochs = 100

"""Initial learning rate"""
learning_rate= 1

"""Learning rate schedule. Signifies by what factor to divide the learning rate
at a certain epoch. For example {5:10} would divide the learning rate by 10
before the 5th epoch and {5:10, 10:100} would divide the learning rate by 10
before the 5th epoch and then again by 100 before the 10th epoch"""
lr_schedule = {}

"""loss criterion, see https://pytorch.org/docs/stable/nn.html for other options"""
criterion = nn.NLLLoss()

# %%
"""******************************************************************
********************NO NEED TO ALTER ANYTHING BELOW******************
******************************************************************"""

use_cuda = torch.cuda.is_available()


"""for plotting of the loss"""
plt.switch_backend('agg')

output_file_name = "testdata.%s_trim.%s_vocab.%s_directions.%s_layers.%s_hidden.%s_dropout.%s_learningrate.%s_batch.%s_epochs.%s" % (dataset,trim,max_vocab_size,directions,layers,hidden_size,dropout,learning_rate,batch_size,epochs)

if create_txt:
	print_to = output_file_name+'.txt'
	with open(print_to, 'w+') as f:
		f.write("Starting Training \n")
else:
	print_to = None

input_lang, output_lang, train_pairs, test_pairs = prepareData(
    input_lang_name, output_lang_name, raw_data_file_path, 
    max_vocab_size=max_vocab_size, reverse=reverse, trim=trim, 
    start_filter=start_filter, perc_train_set=perc_train_set, print_to=print_to)
print('Train Pairs #')
print(len(train_pairs))


"""for gradient clipping from 
https://github.com/pytorch/examples/blob/master/word_language_model/main.py"""
parser = argparse.ArgumentParser(description='PyTorch Wikitext-2 RNN/LSTM Language Model')
parser.add_argument('--clip', type=float, default=0.25,
                    help='gradient clipping')
args = parser.parse_args()

mem()

if create_txt:
	with open(print_to, 'a') as f:
		f.write("\nRandom Train Pair: %s \n\nRandom Test Pair: %s \n\n" 
            % (random.choice(train_pairs),random.choice(test_pairs) 
               if test_pairs else "None"))
		f.write(mem())


"""create the Encoder"""
encoder = EncoderRNN(input_lang.vocab_size, hidden_size, layers=layers, 
                     dropout=dropout, bidirectional=bidirectional)

"""create the Decoder"""
decoder = DecoderAttn(hidden_size, output_lang.vocab_size, layers=layers, 
                      dropout=dropout, bidirectional=bidirectional)

print('Encoder and Decoder Created')
mem()

if use_cuda:
	print('Cuda being used')
	encoder = encoder.cuda()
	decoder = decoder.cuda()

print('Number of epochs: '+str(epochs))

if create_txt:
	with open(print_to, 'a') as f:
		f.write('Encoder and Decoder Created\n')
		f.write(mem())
		f.write("Number of epochs %s \n" % (epochs))

train_and_test(epochs, test_eval_every, plot_every, learning_rate, lr_schedule, 
               train_pairs, test_pairs, input_lang, output_lang, batch_size, 
               test_batch_size, encoder, decoder, criterion, trim, save_weights)
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 10853 sentence pairs
# Counting words...
# Train pairs: 10853
# Test pairs: 0
# Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):
# en, 4487 -> 4490
# fre, 2923 -> 2926
#
# Train Pairs #
# 10853
# Current mem usage:
# 19.3595904
# Current mem usage:
# 19.3595904
# Encoder and Decoder Created
# Current mem usage:
# 19.3595904
# Cuda being used
# Number of epochs: 100
# Current mem usage:
# 28.2532352
# Iter: 1
# Learning Rate: 1
# Time: 0h 0m 16s
# Train Loss: 2.6222649392047046
#
# > je suis pour toujours ton debiteur .
# = i am forever in your debt .
# < i m not to to you . <EOS>
#
# > il exerce sur elle du chantage .
# = she is being blackmailed by him .
# < he is a a a to a to a . <EOS>
#
# > nous sommes tous decus .
# = we re all disappointed .
# < we re the . <EOS>
#
# > nous sommes dans le meme bateau .
# = we re in the same boat .
# < we re not the . <EOS>
#
# > je suis a vous .
# = i m yours .
# < i m not to you . <EOS>
#
# > je suis intrepide .
# = i m fearless .
# < i m to to . . <EOS>
#
# > je ne suis pas assez bonne pour vous .
# = i m not good enough for you .
# < i m not not you . <EOS>
#
# > tu es fort curieuse .
# = you re very curious .
# < you re not . <EOS>
#
# > tu te comportes comme un enfant .
# = you re acting like a child .
# < you re not the . <EOS>
#
# > ils sont extenues .
# = they are exhausted .
# < we re the . <EOS>
#
# Iter: 2
# Learning Rate: 1
# Time: 0h 0m 32s
# Train Loss: 1.979439106631458
#
# > nous ne sommes pas perdus .
# = we re not lost .
# < we re not to to we we . <EOS>
#
# > je suis desolee de vous avoir blesse .
# = i m sorry i hurt you .
# < i m glad i i i i i i to i i i i you . <EOS>
#
# > vous n etes pas censees nager ici .
# = you aren t supposed to swim here .
# < you re not to to t . <EOS>
#
# > nous sommes intelligents .
# = we re smart .
# < we re all . <EOS>
#
# > je suis boulangere .
# = i m a baker .
# < i m a to a a a . <EOS>
#
# > ils ont peur de la mort .
# = they are afraid of death .
# < they re to to to the the the the of the the . <EOS>
#
# > je suis tres fatigue .
# = i m very tired .
# < i m to to i i to i a a a a . <EOS>
#
# > je ne suis pas folle .
# = i m not insane .
# < i m not to to i i your of your . <EOS>
#
# > tu es trop poli .
# = you re too polite .
# < you re a a a a a a . <EOS>
#
# > vous etes tres talentueuse .
# = you re very talented .
# < you re a a a a a a a a a a a . <EOS>
#
# Iter: 3
# Learning Rate: 1
# Time: 0h 0m 49s
# Train Loss: 1.7714136552826298
#
# > je le fais pour toi .
# = i m doing this for you .
# < i m too to for you . <EOS>
#
# > je me fais du souci a leur sujet .
# = i m worried about them .
# < i m sorry to i my my the . <EOS>
#
# > nous sommes satisfaites .
# = we re satisfied .
# < we re a the the the we . <EOS>
#
# > je vais y repenser encore une fois .
# = i m going to reconsider it .
# < i m going to a a a a a good . <EOS>
#
# > elle ne devrait pas y aller seule .
# = she shouldn t go by herself .
# < she not not going to that . <EOS>
#
# > j espere avoir de tes nouvelles .
# = i m looking forward to hearing from you .
# < i m sorry to i my my . <EOS>
#
# > je ne te drague pas .
# = i m not hitting on you .
# < i m not t you . <EOS>
#
# > il est ivre mort .
# = he is dead drunk .
# < he s a a good . <EOS>
#
# > il ment mal .
# = he s a bad liar .
# < he s a his his his . <EOS>
#
# > je ramene une pizza chez moi .
# = i m bringing home a pizza .
# < i m a my my my my my my . <EOS>
#
# Iter: 4
# Learning Rate: 1
# Time: 0h 1m 5s
# Train Loss: 1.5901502815866722
#
# > vous etes branchee .
# = you re fashionable .
# < you re too . <EOS>
#
# > je m ennuie a mourir .
# = i m bored to death .
# < i m sorry to i my my him . <EOS>
#
# > tu es invite .
# = you re invited .
# < you re too . <EOS>
#
# > je ne vais pas mourir .
# = i m not going to die .
# < i m not going to be it . <EOS>
#
# > nous partons pour hawai ce soir .
# = we are leaving for hawaii tonight .
# < we re going to for this . <EOS>
#
# > je suis le capitaine .
# = i m the captain .
# < i m the the the the the teacher . <EOS>
#
# > je suis un joueur de foot .
# = i m a football player .
# < i m a little of man . <EOS>
#
# > tu es tres gentil .
# = you re very nice .
# < you re very very good . <EOS>
#
# > ils sont saouls .
# = they re drunk .
# < they re all all . <EOS>
#
# > je suis sur qu il partira tot .
# = i m sure he ll leave early .
# < i m sure he he be at it . <EOS>
#
# Iter: 5
# Learning Rate: 1
# Time: 0h 1m 21s
# Train Loss: 1.457615634364326
#
# > elle est affutee .
# = she is sharp .
# < she is a bad . <EOS>
#
# > vous etes grands .
# = you re big .
# < you re a good . <EOS>
#
# > je reste pour quelques autres semaines .
# = i am staying for another few weeks .
# < i m going to be be the same . <EOS>
#
# > il est peintre .
# = he is a painter .
# < he is a good . <EOS>
#
# > nous ne faisons que commencer .
# = we re just beginning .
# < we re just as as as am . <EOS>
#
# > il est toujours en retard a l ecole .
# = he s always late for school .
# < he is very at the same . <EOS>
#
# > elle est plus sage qu intelligente .
# = she is more wise than clever .
# < she is as as as as is . <EOS>
#
# > nous n allons nulle part .
# = we re not going anywhere .
# < we re not going to be a good . <EOS>
#
# > nous n en avons pas fini .
# = we re not finished .
# < we re not sure . <EOS>
#
# > j essaye de sauver la vie de tom .
# = i m trying to save tom s life .
# < i m afraid of the his his . <EOS>
#
# Iter: 6
# Learning Rate: 1
# Time: 0h 1m 37s
# Train Loss: 1.3343252884056167
#
# > je suis sur .
# = i m certain .
# < i m sure . <EOS>
#
# > elle est habituee a se lever tot .
# = she s accustomed to getting up early .
# < she is to be happy . <EOS>
#
# > tu n y es pas en securite .
# = you re not safe there .
# < you re not in this . <EOS>
#
# > il adore les chats .
# = he s a cat lover .
# < he is his his his her . <EOS>
#
# > j ecris un roman .
# = i m writing a novel .
# < i m a little a little car . <EOS>
#
# > vous avez tort dans ce cas .
# = you re wrong in this case .
# < you re in the same time . <EOS>
#
# > il est probable qu il vienne .
# = he s likely to come .
# < he is likely to he his his father . <EOS>
#
# > je fais la fete .
# = i m celebrating .
# < i m in the the teacher . <EOS>
#
# > je suis vraiment en colere la .
# = i m really angry right now .
# < i m really really at all . <EOS>
#
# > vous etes tres chouette .
# = you re very nice .
# < you re very very busy . <EOS>
#
# Iter: 7
# Learning Rate: 1
# Time: 0h 1m 54s
# Train Loss: 1.2370590094307217
#
# > c est une veritable artiste .
# = she s a true artist .
# < she is a little girl . <EOS>
#
# > je suis votre amie .
# = i m your friend .
# < i m your your friend . <EOS>
#
# > tu es plein de ressources .
# = you re very resourceful .
# < you re very very of . <EOS>
#
# > je suis celui qui a construit ceci .
# = i m the one who built this .
# < i am the one who who me . <EOS>
#
# > je ne tiens pas en place .
# = i m restless .
# < i m not in this this . <EOS>
#
# > vous etes fort ingenieux .
# = you re very clever .
# < you re very very busy . <EOS>
#
# > elles sont etudiantes .
# = they re students .
# < they re good . <EOS>
#
# > vous etes extraverti .
# = you re extroverted .
# < you re young . <EOS>
#
# > je survis .
# = i m surviving .
# < i m feeling hungry . <EOS>
#
# > tu n es pas invitee .
# = you aren t invited .
# < you re not that that . <EOS>
#
# Iter: 8
# Learning Rate: 1
# Time: 0h 2m 10s
# Train Loss: 1.1522812529651107
#
# > j ai faim !
# = i m hungry !
# < i m tired . <EOS>
#
# > il ecrit son journal .
# = he s writing his diary .
# < he is his his father . <EOS>
#
# > je lis le new york times .
# = i m reading the new york times .
# < i m doing the new next next next time . <EOS>
#
# > je suis plus belle que toi .
# = i am more beautiful than you .
# < i m smarter than you . <EOS>
#
# > vous etes plus grands que moi .
# = you are taller than me .
# < you re taller than me . <EOS>
#
# > je ne vais pas bien du tout .
# = i am not well at all .
# < i m not all at all all . <EOS>
#
# > je pars pour le canada demain .
# = i m leaving for canada tomorrow .
# < i m going to the same tomorrow . <EOS>
#
# > je suis tres interesse par la musique .
# = i am very interested in music .
# < i m very busy in the same . <EOS>
#
# > je suis impulsif .
# = i m impulsive .
# < i m a friend . <EOS>
#
# > nous sommes toutes pretes .
# = we are all set .
# < we re all late . <EOS>
#
# Iter: 9
# Learning Rate: 1
# Time: 0h 2m 26s
# Train Loss: 1.0694716254596597
#
# > vous etes la doyenne .
# = you re the oldest .
# < you re the teacher . <EOS>
#
# > elles sont de grandes amies .
# = they are great friends .
# < they are friends with the new time . <EOS>
#
# > tu es cruelle .
# = you re cruel .
# < you re in wrong . <EOS>
#
# > je suis content que tu m aies invite .
# = i m glad you invited me .
# < i m glad you re me . <EOS>
#
# > elles se trouvent juste derriere toi .
# = they re right behind you .
# < they re right behind you . <EOS>
#
# > je crains que tu m aies mal compris .
# = i m afraid you misunderstood me .
# < i m afraid you liked that out . <EOS>
#
# > je suis desole je ne comprends pas .
# = i m sorry i don t understand .
# < i m sorry i don t t recognize . <EOS>
#
# > elle est mal elevee .
# = she is bad mannered .
# < she is good at english . <EOS>
#
# > il lave sa voiture .
# = he is washing his car .
# < he is his his car . <EOS>
#
# > nous nous dirigeons vers le sud .
# = we re going south .
# < we re going to us the same . <EOS>
#
# Iter: 10
# Learning Rate: 1
# Time: 0h 2m 43s
# Train Loss: 1.0018500862180975
#
# > je suis presque pret .
# = i m about ready .
# < i m ready ready to am . <EOS>
#
# > tu deviens rouge .
# = you re turning red .
# < you re going to go now . <EOS>
#
# > je n y suis pas interessee .
# = i m not interested in that .
# < i m not at that that . <EOS>
#
# > tu m evites .
# = you re avoiding me .
# < you re free me . <EOS>
#
# > nous sommes consciencieuses .
# = we re conscientious .
# < we re ready . <EOS>
#
# > il est actuellement sorti .
# = he is out now .
# < he is a teacher now . <EOS>
#
# > ils sont chretiens .
# = they are christians .
# < they are angry . <EOS>
#
# > vous etes un puritain .
# = you re a prude .
# < you re a liar . <EOS>
#
# > j en suis convaincu .
# = i m convinced .
# < i m sick of that . <EOS>
#
# > nous sommes tout a fait seuls .
# = we re quite alone .
# < we re all ready . <EOS>
#
# Iter: 11
# Learning Rate: 1
# Time: 0h 2m 59s
# Train Loss: 0.9369545749975635
#
# > je deviens chauve .
# = i m going bald .
# < i m going to eating a cold . <EOS>
#
# > je n en suis pas si sure !
# = i m not so sure .
# < i m not that sure i don <EOS>
#
# > il est pauvre mais heureux .
# = he is poor but happy .
# < he is well but as very happy . <EOS>
#
# > elles sont fatiguees .
# = they re tired .
# < they re tired . <EOS>
#
# > tu es lunatique .
# = you re moody .
# < you re a good person . <EOS>
#
# > nous nous retirons .
# = we re pulling back .
# < we re going to us . <EOS>
#
# > je suis femme au foyer .
# = i m a housewife .
# < i m a student . <EOS>
#
# > il est un bon perdant .
# = he is a good loser .
# < he s a good good good . <EOS>
#
# > je suis tout a fait eveille .
# = i m wide awake .
# < i m all out of all . <EOS>
#
# > nous ne sommes pas fous .
# = we re not mad .
# < we re not invited . <EOS>
#
# Iter: 12
# Learning Rate: 1
# Time: 0h 3m 15s
# Train Loss: 0.8824965254825207
#
# > je ne suis pas vraiment en colere .
# = i m not really angry .
# < i m not really angry . <EOS>
#
# > vous n etes pas seules .
# = you re not alone .
# < you aren t alone . <EOS>
#
# > je suis en train d ecrire un bouquin .
# = i m writing a book .
# < i am reading a job . <EOS>
#
# > tu caches quelque chose .
# = you re hiding something .
# < you re going to miss a fast . <EOS>
#
# > vous etes ma princesse .
# = you re my princess .
# < you my my friend . <EOS>
#
# > nous sommes tous deux fous .
# = we re both insane .
# < we re both both today . <EOS>
#
# > je suis tres en faveur de cela .
# = i m very much in favor of this .
# < i m very kind of that . <EOS>
#
# > c est maree basse .
# = you re out of booze .
# < i m out of the love . <EOS>
#
# > nous sommes la pour jouer au basket .
# = we re here to play basketball .
# < we re here to the same team . <EOS>
#
# > nous n en sommes pas encore convaincus .
# = we re not convinced yet .
# < we re not sure yet . <EOS>
#
# Iter: 13
# Learning Rate: 1
# Time: 0h 3m 32s
# Train Loss: 0.8270059451788067
#
# > je suis fatigue de ce temps chaud .
# = i m sick of this hot weather .
# < i m tired of this time time . <EOS>
#
# > il se trouve juste derriere toi .
# = he s right behind you .
# < he s right behind you . <EOS>
#
# > elle est une mere tres avisee .
# = she s a very wise mother .
# < she s a very very nice boy . <EOS>
#
# > elle est super .
# = she s awesome .
# < she is a bad person . <EOS>
#
# > j ai faim !
# = i am hungry .
# < i m hungry if i thirsty <EOS>
#
# > nous nous faisons du souci pour votre securite .
# = we re concerned for your safety .
# < we are looking forward to your help . <EOS>
#
# > tu deformes mes paroles .
# = you re twisting my words .
# < you are wasting my new book . <EOS>
#
# > je retourne en fac .
# = i m going back to college .
# < i m going to be late . <EOS>
#
# > je suis un professeur de japonais .
# = i m a japanese teacher .
# < i m a good man . <EOS>
#
# > je suis plutot content .
# = i m fairly happy .
# < i m happy happy . <EOS>
#
# Iter: 14
# Learning Rate: 1
# Time: 0h 3m 48s
# Train Loss: 0.7768639103696604
#
# > c est un vrai mec .
# = he s a real man .
# < he is a man of s tough . <EOS>
#
# > je ne suis pas grande .
# = i m not tall .
# < i m not a millionaire person . <EOS>
#
# > elle va avoir un bebe .
# = she s going to have a baby .
# < she is going to have a cold . <EOS>
#
# > elle a certainement plus de quarante ans .
# = she is certainly over forty .
# < she is ashamed of three three three years . <EOS>
#
# > elle est son amie .
# = she is her friend .
# < she is her friend of her friend . <EOS>
#
# > tu es mon obsession .
# = you are very dear to me .
# < you are my hero of my hero . <EOS>
#
# > vous etes talentueuses .
# = you re talented .
# < you re very talented . <EOS>
#
# > c est un sacre musicien .
# = he is something of a musician .
# < he is a real artist . <EOS>
#
# > elle l a vu a la gare .
# = she saw him at the station .
# < she saw him him . <EOS>
#
# > il est endormi .
# = he is asleep .
# < he is busy about it . <EOS>
#
# Iter: 15
# Learning Rate: 1
# Time: 0h 4m 4s
# Train Loss: 0.7360868512783156
#
# > je suis celle qui a construit ceci .
# = i m the one who built this .
# < i m the one who trained this . <EOS>
#
# > j achete un chiot .
# = i m buying a puppy .
# < i m taking a lot of a lot . <EOS>
#
# > nous sommes a court d argent .
# = we are short of money .
# < we are sure of money . <EOS>
#
# > je ne suis pas interessee par une relation .
# = i m not interested in a relationship .
# < i m not interested in a letter . <EOS>
#
# > c est un menteur notoire .
# = he s a notorious liar .
# < he s a wonderful young . <EOS>
#
# > il est bien paye .
# = he is well paid .
# < he is well well english english . <EOS>
#
# > je ne suis pas egoiste .
# = i m not selfish .
# < i m not desperate . <EOS>
#
# > je me rejouis que nous l ayons fait .
# = i m glad we did that .
# < i m glad we can it . <EOS>
#
# > je suis impatiente de te revoir .
# = i am looking forward to seeing you again .
# < i m looking forward to seeing you again . <EOS>
#
# > je suis faible .
# = i m weak .
# < i m impressed . <EOS>
#
# Iter: 16
# Learning Rate: 1
# Time: 0h 4m 21s
# Train Loss: 0.6904774967782508
#
# > nous sommes journalistes .
# = we re journalists .
# < we re out of we . <EOS>
#
# > je ne suis pas du genre jaloux .
# = i m not the jealous type .
# < i m not the mood . <EOS>
#
# > vous etes aveugles par l amour .
# = you are blinded by love .
# < you are blinded by love . <EOS>
#
# > elle lui a envoye une carte postale .
# = she sent him a postcard .
# < she saw him a cold . <EOS>
#
# > je vous le demande en tant qu ami .
# = i m asking you as a friend .
# < i m asking you as a friend . <EOS>
#
# > tu n es pas de mes amis .
# = you re no friend of mine .
# < you re not my friend of friends . <EOS>
#
# > il est a velo .
# = he is riding a bicycle .
# < he s a heroin drunk . <EOS>
#
# > tu es un opportuniste .
# = you re opportunistic .
# < you are a man . <EOS>
#
# > nous ne sommes pas serieux .
# = we re not serious .
# < we re not serious . <EOS>
#
# > elles sont mignonnes .
# = they re cute .
# < they are jealous . <EOS>
#
# Iter: 17
# Learning Rate: 1
# Time: 0h 4m 37s
# Train Loss: 0.6494947156059047
#
# > il a travaille toute la journee .
# = he s been working all day long .
# < he s working working in music . <EOS>
#
# > nous sommes bourres .
# = we re smashed .
# < we re out of we luck . <EOS>
#
# > je ne suis pas celui que tu penses .
# = i m not who you think i am .
# < i m not who you think i am . <EOS>
#
# > tu es genial .
# = you re awesome .
# < you re all crazy . <EOS>
#
# > il est trop honnete pour dire un mensonge .
# = he is too honest to tell a lie .
# < he is too old to call a job . <EOS>
#
# > c est une femme d interieur accomplie .
# = she s the perfect housewife .
# < she is a real woman of the world . <EOS>
#
# > je ne conteste pas cela .
# = i m not disputing that .
# < i m not not that that . <EOS>
#
# > je vais cuisiner pour vous .
# = i m going to cook for you .
# < i m going to be on you . <EOS>
#
# > il est en danger grave .
# = he s in grave danger .
# < he is in danger of danger . <EOS>
#
# > tu me mets mal a l aise .
# = you re embarrassing me .
# < you re never me hard . <EOS>
#
# Iter: 18
# Learning Rate: 1
# Time: 0h 4m 54s
# Train Loss: 0.6087246514273178
#
# > tu n es pas ainsi d ordinaire .
# = you re not usually like this .
# < you re not supposed to find . <EOS>
#
# > je vais dormir .
# = i m going to sleep .
# < i am going to take the go . <EOS>
#
# > il s approche .
# = he s coming closer .
# < he s getting getting been late . <EOS>
#
# > elle rassemble du materiel pour un livre .
# = she s collecting material for a book .
# < she is taking up for a book . <EOS>
#
# > j ai une mauvaise impression .
# = i m getting a bad feeling .
# < i m a little hungry . <EOS>
#
# > j essaye de sauver la vie de tom .
# = i m trying to save tom s life .
# < i m trying to swim tom s car . <EOS>
#
# > il etudie tout le temps .
# = he is always studying .
# < he is always studying time . <EOS>
#
# > il est normalement chez lui le soir .
# = he is generally at home in the evening .
# < he is busy at home in the way . <EOS>
#
# > je suis nerveuse et excitee .
# = i m nervous and excited .
# < i m pleased and embarrassed i m sleepy . <EOS>
#
# > vous n etes pas assez rapide .
# = you re not fast enough .
# < you re not good enough . <EOS>
#
# Iter: 19
# Learning Rate: 1
# Time: 0h 5m 10s
# Train Loss: 0.5733801093034295
#
# > nous sommes impuissantes .
# = we re powerless .
# < we re out . <EOS>
#
# > je suis aussi curieuse que vous .
# = i m as curious as you are .
# < i m as curious as you are . <EOS>
#
# > je suis impatient .
# = i m impatient .
# < i m too forward . <EOS>
#
# > je suis sobre .
# = i m sober .
# < i m retired . <EOS>
#
# > tu arrives trop tard .
# = you are too late .
# < you re too late . <EOS>
#
# > il est en etat de choc .
# = he s in a state of shock .
# < he s in a world school . <EOS>
#
# > elle lui dit quelque chose .
# = she said something to him .
# < she said him something . <EOS>
#
# > ils sont chanteurs .
# = they are singers .
# < they are mine . <EOS>
#
# > il joue avec ma chatte .
# = he s playing with my cat .
# < he is playing with my girlfriend . <EOS>
#
# > tu es grande .
# = you are big .
# < you are big beautiful . <EOS>
#
# Iter: 20
# Learning Rate: 1
# Time: 0h 5m 26s
# Train Loss: 0.5425633917984825
#
# > elle a l air de venir .
# = she is likely to come .
# < she is very afraid to be . <EOS>
#
# > ils sont tous terrifies .
# = they re all terrified .
# < they are all all alike . <EOS>
#
# > tu fais tout ce que tu peux .
# = you re doing all you can .
# < you re doing all you can . <EOS>
#
# > vous etes tres solitaire .
# = you re very lonely .
# < you are very very lonely . <EOS>
#
# > je suis deja mariee .
# = i m already married .
# < i m already married . <EOS>
#
# > je viens d angleterre .
# = i am from england .
# < i m from hearing . <EOS>
#
# > je me rejouis que vous soyez venu .
# = i m glad you came over .
# < i m glad you came over . <EOS>
#
# > il a trois ans de plus que moi .
# = he s three years older than i am .
# < he s three years older than i am . <EOS>
#
# > je suis stricte .
# = i m strict .
# < i m impressed . <EOS>
#
# > tu n es pas si folle .
# = you re not that crazy .
# < you re not that that mine . <EOS>
#
# Iter: 21
# Learning Rate: 1
# Time: 0h 5m 43s
# Train Loss: 0.5076162988476889
#
# > je suis gave .
# = i m stuffed .
# < i m glad . <EOS>
#
# > je n en ai pas fini avec vous .
# = i m not done with you .
# < i m not finished with you . <EOS>
#
# > je n ai absolument pas peur .
# = i m not afraid at all .
# < i m not afraid about it . <EOS>
#
# > je suis terrible avec les enfants .
# = i m horrible with kids .
# < i m surprised with kids . <EOS>
#
# > nous sortons ensemble .
# = we re dating .
# < we re out of a problem . <EOS>
#
# > je suis la plus vieille .
# = i m the oldest .
# < i m the oldest . <EOS>
#
# > je suis membre de l equipe .
# = i m a member of the team .
# < i m a fan of the team . <EOS>
#
# > je ne suis pas un robot .
# = i m not a robot .
# < i m not a drug addict . <EOS>
#
# > je suis en train de travailler .
# = i am working .
# < i m working . <EOS>
#
# > il a honte de poser des questions .
# = he is ashamed to ask questions .
# < he is ashamed to making mistakes . <EOS>
#
# Iter: 22
# Learning Rate: 1
# Time: 0h 5m 59s
# Train Loss: 0.47800675757554145
#
# > ils sont en dessous .
# = they re downstairs .
# < they re downstairs . <EOS>
#
# > elle est affairee .
# = she s busy with her work .
# < she s busy that s busy . <EOS>
#
# > je suis veinard .
# = i m in luck .
# < i m in a stranger . <EOS>
#
# > il est respecte de tout le monde .
# = he is respected by everybody .
# < he is by everybody . <EOS>
#
# > je suis trop fatigue pour me disputer .
# = i m too tired to argue .
# < i m too tired to argue . <EOS>
#
# > il vous attend chez lui .
# = he s waiting for you at home .
# < he s waiting for you at home . <EOS>
#
# > il est assez mignon n est ce pas ?
# = he s kind of cute isn t he ?
# < he s kind of cute isn t he ? <EOS>
#
# > je suis fatiguee de danser .
# = i m tired of dancing .
# < i m tired of reading . <EOS>
#
# > c est un homme de foi .
# = he is a man of faith .
# < he is a man of college . <EOS>
#
# > il ne faut pas nous deranger .
# = we re not to be disturbed .
# < we re not to be disturbed . <EOS>
#
# Iter: 23
# Learning Rate: 1
# Time: 0h 6m 15s
# Train Loss: 0.4480797954482433
#
# > tu n es pas si interessant .
# = you re not that interesting .
# < you re not that interesting . <EOS>
#
# > j appelle la securite .
# = i m calling security .
# < i m calling early in the way . <EOS>
#
# > je suis votre plus grand fan .
# = i m your biggest fan .
# < i m your biggest fan . <EOS>
#
# > nous nous ennuyons .
# = we re bored .
# < we re getting bored . <EOS>
#
# > tu t embrouilles a nouveau non ?
# = you re confused again aren t you ?
# < you re confused again aren t you ? <EOS>
#
# > je suis desolee si je vous ai embarrassee .
# = i m sorry if i embarrassed you .
# < i m sorry if i embarrassed you . <EOS>
#
# > je l emporte .
# = i m winning .
# < i am thinking to the name . <EOS>
#
# > je ne suis pas sur de comprendre .
# = i m not sure i understand .
# < i m not sure i understand . <EOS>
#
# > il est sur le point de mourir .
# = he is about to die .
# < he s about to die . <EOS>
#
# > il n est pas du tout un gentleman .
# = he is not at all a gentleman .
# < he is not at all a gentleman . <EOS>
#
# Iter: 24
# Learning Rate: 1
# Time: 0h 6m 32s
# Train Loss: 0.4220344193370097
#
# > il est actuellement a l exterieur .
# = he s out now .
# < he s out to blame now . <EOS>
#
# > c est un marcheur rapide .
# = he s a fast walker .
# < he is a fast to drink . <EOS>
#
# > il vient de sortir de l universite .
# = he is fresh from college .
# < he s fresh out of college . <EOS>
#
# > je ne suis pas en forme .
# = i m not in good shape .
# < i m not in that . <EOS>
#
# > elle est ma camarade de classe .
# = she is my classmate .
# < she is my older of the dark . <EOS>
#
# > j ai faim !
# = i m hungry !
# < i m hungry hungry . <EOS>
#
# > je suis calme .
# = i am calm .
# < i m retired . <EOS>
#
# > je vais cuisiner pour vous .
# = i m going to cook for you .
# < i m going to call you . <EOS>
#
# > j arrive chez moi .
# = i m coming home .
# < i m home home . <EOS>
#
# > je m amuse .
# = i m having fun .
# < i m getting out of myself . <EOS>
#
# Iter: 25
# Learning Rate: 1
# Time: 0h 6m 48s
# Train Loss: 0.39696853549235844
#
# > elle est agressive .
# = she is aggressive .
# < she is a lonely . <EOS>
#
# > il se comporte etrangement .
# = he s behaving oddly .
# < he seems to speak up up . <EOS>
#
# > nous allons tous chez nous .
# = we re all going home .
# < we re all going home . <EOS>
#
# > il fait des progres .
# = he s making progress .
# < he is making taking progress . <EOS>
#
# > j essaye d apprendre l anglais .
# = i am trying to learn english .
# < i m trying to be english . <EOS>
#
# > vous etes fort bonne .
# = you re very good .
# < you re very good . <EOS>
#
# > vous etes odieux .
# = you re obnoxious .
# < you re out of booze . <EOS>
#
# > elle ne convient pas a la tache .
# = she isn t adequate to the task .
# < she isn t talking . <EOS>
#
# > t es pas aussi maligne que moi .
# = you re not as smart as me .
# < you re not as smart as me . <EOS>
#
# > nous sommes des nouveaux venus .
# = we re newcomers .
# < we re newcomers . <EOS>
#
# Iter: 26
# Learning Rate: 1
# Time: 0h 7m 4s
# Train Loss: 0.37164255520118267
#
# > nous sommes serieuses .
# = we re serious .
# < we re being serious . <EOS>
#
# > il verifie son telephone portable .
# = he s checking his cellphone .
# < he is washing his own cold . <EOS>
#
# > vous etes deux fois plus forts que moi .
# = you are twice as strong as i am .
# < you are twice as strong as i am . <EOS>
#
# > tu es creatif .
# = you re creative .
# < you re mine . <EOS>
#
# > je suis accoutume au temps froid .
# = i am accustomed to cold weather .
# < i m ready to apologize . <EOS>
#
# > nous rejouons .
# = we re taking over .
# < we re getting getting out . <EOS>
#
# > je me remets .
# = i m getting better .
# < i m getting a cold . <EOS>
#
# > tu es un genie .
# = you are a genius .
# < you are a kid . <EOS>
#
# > vous etes odieuse .
# = you re obnoxious .
# < you re unambitious . <EOS>
#
# > elle lui a serre la main .
# = she shook hands with him .
# < she saw him at him . <EOS>
#
# Iter: 27
# Learning Rate: 1
# Time: 0h 7m 21s
# Train Loss: 0.34794565158295104
#
# > il est blinde .
# = he s loaded .
# < he s open . <EOS>
#
# > vous n etes pas autorises a stationner la .
# = you aren t allowed to park there .
# < you aren t allowed to park there . <EOS>
#
# > vous etes tres elegante .
# = you re very sophisticated .
# < you re very attractive . <EOS>
#
# > elle souffre d une maladie grave .
# = she s suffering from a serious disease .
# < she is suffering from a serious serious . <EOS>
#
# > je ne suis pas supposee boire .
# = i m not supposed to drink .
# < i m not supposed to drink . <EOS>
#
# > je suis l un de vous .
# = i m one of you .
# < i m one of you . <EOS>
#
# > vous prechez un convaincu .
# = you re preaching to the choir .
# < you re preaching to the choir . <EOS>
#
# > tu es vraiment magnifique .
# = you re really gorgeous .
# < you re really a funny . <EOS>
#
# > elle a eprouve des difficultes a se lever .
# = she struggled to get up .
# < she struggled to get up . <EOS>
#
# > elle restait proche de son mari .
# = she stood close to her husband .
# < she stood to help her husband . <EOS>
#
# Iter: 28
# Learning Rate: 1
# Time: 0h 7m 37s
# Train Loss: 0.3277430867316564
#
# > je suis simplement franche .
# = i m just being honest .
# < i am just an honest . <EOS>
#
# > nous sommes juste fatiguees .
# = we re just tired .
# < we re just tired . <EOS>
#
# > vous n etes pas differentes .
# = you re no different .
# < you re not a different person . <EOS>
#
# > nous allons bien .
# = we re fine .
# < we re going to be ok . <EOS>
#
# > on nous encourage a utiliser notre imagination .
# = we are encouraged to use our imagination .
# < we are going to give our our song . <EOS>
#
# > je suis paresseuse .
# = i m lazy .
# < i am lazy . <EOS>
#
# > il est riche maintenant .
# = he is well off now .
# < he is busy busy now . <EOS>
#
# > j en suis vraiment fier .
# = i m really proud of it .
# < i m really proud of this . <EOS>
#
# > je ne suis personne de special .
# = i m no one special .
# < i m no one special . <EOS>
#
# > vous etes branchee .
# = you re fashionable .
# < you are one . <EOS>
#
# Iter: 29
# Learning Rate: 1
# Time: 0h 7m 53s
# Train Loss: 0.30524589162660587
#
# > vous etes quelqu un de mechant .
# = you are a mean person .
# < you re a funny guy . <EOS>
#
# > elle se rejouit de donner .
# = she is a cheerful giver .
# < she is a lot of problems . <EOS>
#
# > je suis plus beau que vous .
# = i am more beautiful than you .
# < i m more beautiful than you . <EOS>
#
# > vous etes tous des racistes .
# = you re all racists .
# < you re all racists . <EOS>
#
# > tu n es pas suppose te trouver la .
# = you re not supposed to be here .
# < you re not supposed to be here . <EOS>
#
# > elle est japonaise .
# = she is japanese .
# < she is japanese . <EOS>
#
# > je suis heureuse que vous l ayez aime .
# = i m happy you liked it .
# < i m happy you liked it . <EOS>
#
# > je ne suis pas une ivrogne .
# = i m not a drunk .
# < i m not a drug addict . <EOS>
#
# > vous n etes plus mon amie .
# = you re not my friend anymore .
# < you re not my friend anymore . <EOS>
#
# > demain je jouerai au football .
# = i am going to play soccer tomorrow .
# < i m going to play the study . <EOS>
#
# Iter: 30
# Learning Rate: 1
# Time: 0h 8m 10s
# Train Loss: 0.2869653054355834
#
# > tu es libere de toute responsabilite .
# = you re free of all responsibility .
# < you re free of all responsibility . <EOS>
#
# > nous nous rechauffons .
# = we re getting warmer .
# < we re getting bored . <EOS>
#
# > je suis daltonien .
# = i m color blind .
# < i m being flattered out . <EOS>
#
# > nous sommes remuees .
# = we re shaken .
# < we re satisfied . <EOS>
#
# > je le fais malgre vous .
# = i m doing it in spite of you .
# < i m doing it in spite of you . <EOS>
#
# > je suis tres occupe cette semaine .
# = i m very busy this week .
# < i m very busy this week . <EOS>
#
# > tu es chanceuse .
# = you re fortunate .
# < you re fortunate . <EOS>
#
# > tu es le seul ami que j aie .
# = you re the only friend i have .
# < you re the only friend i have . <EOS>
#
# > c est vous l instituteur .
# = you re the teacher .
# < you re the teacher . <EOS>
#
# > vous etes tres craintive .
# = you re very timid .
# < you re very timid . <EOS>
#
# Iter: 31
# Learning Rate: 1
# Time: 0h 8m 26s
# Train Loss: 0.2676435030510839
#
# > il cuisine a la demande .
# = he s a short order cook .
# < he s a professor at s house . <EOS>
#
# > je ne reviens pas .
# = i m not coming back .
# < i m not leaving . <EOS>
#
# > j adore prendre des photos .
# = i m fond of taking pictures .
# < i m taking taking taking pictures . <EOS>
#
# > il porte un chapeau .
# = he is wearing a hat .
# < he is wearing a hat . <EOS>
#
# > tu es fort sceptique .
# = you re very skeptical .
# < you re very skeptical . <EOS>
#
# > je suis impliquee .
# = i m involved .
# < i m lonely . <EOS>
#
# > je m amuse .
# = i m having fun .
# < i am getting out of this out . <EOS>
#
# > je vais etre ton avocat .
# = i m going to be your lawyer .
# < i m going to be your lawyer . <EOS>
#
# > il s interesse aux propheties mayas .
# = he s interested in mayan prophecies .
# < he s interested in taking cold . <EOS>
#
# > il est loin d etre riche .
# = he is far from rich .
# < he is far from rich . <EOS>
#
# Iter: 32
# Learning Rate: 1
# Time: 0h 8m 42s
# Train Loss: 0.2506181769822707
#
# > je suis tres fier de nos etudiants .
# = i m very proud of our students .
# < i m very proud of our students . <EOS>
#
# > il est fou .
# = he s demented .
# < he s mad at the manager . <EOS>
#
# > il respire avec difficulte .
# = he is breathing hard .
# < he s hiding on hiding . <EOS>
#
# > je suis sur que vous serez satisfaits .
# = i am sure that you will be satisfied .
# < i m sure you re all that . <EOS>
#
# > t a plus de bibine .
# = you re out of booze .
# < you re out of booze . <EOS>
#
# > vous etes insupportable .
# = you are impossible .
# < you re the same . <EOS>
#
# > ce n est pas un eleve ordinaire .
# = he is no ordinary student .
# < he is no ordinary student . <EOS>
#
# > j en ai marre de cette guerre .
# = i m sick of this war .
# < i m tired of this evening . <EOS>
#
# > je suis heureux que tu puisses venir .
# = i m glad that you can come .
# < i m glad you can come . <EOS>
#
# > je te suis reconnaissant pour ta gentillesse .
# = i am grateful to you for your kindness .
# < i am grateful to you for your kindness . <EOS>
#
# Iter: 33
# Learning Rate: 1
# Time: 0h 8m 59s
# Train Loss: 0.23416553280541896
#
# > elle est en bons termes avec lui .
# = she is on friendly terms with him .
# < she is good at her him . <EOS>
#
# > elle a honte de ses vieux vetements .
# = she is ashamed of her old clothes .
# < she is ashamed of her old old for old . <EOS>
#
# > tu es un bon journaliste .
# = you re a good journalist .
# < you re a good journalist . <EOS>
#
# > ils sont en train de se disputer .
# = they re arguing .
# < they re arguing . <EOS>
#
# > nous nous retirons .
# = we re pulling out .
# < we re getting close . <EOS>
#
# > il est respecte par tout le monde .
# = he is respected by everyone .
# < he is respected by everyone . <EOS>
#
# > je ne parle pas avec toi .
# = i m not talking to you .
# < i m not talking to you . <EOS>
#
# > il est a la hauteur de la tache .
# = he is equal to the task .
# < he is equal to the task . <EOS>
#
# > c est mon frere .
# = he is my brother .
# < he is my brother to brother . <EOS>
#
# > elle est ivre de bonheur .
# = she is drunk with happiness .
# < she is drunk with a bit drunk . <EOS>
#
# Iter: 34
# Learning Rate: 1
# Time: 0h 9m 15s
# Train Loss: 0.218338090480253
#
# > je ne vais pas manger ca .
# = i m not eating this .
# < i m not going to figure this . <EOS>
#
# > je crains que la rumeur ne soit averee .
# = i m afraid the rumor is true .
# < i m afraid the rumor is true . <EOS>
#
# > il se trompe completement .
# = he is sadly mistaken .
# < he s completely completely running . <EOS>
#
# > j essaye toujours .
# = i m still trying .
# < i m always trying to always involved . <EOS>
#
# > tu es garee en double file .
# = you re double parked .
# < you re double parked . <EOS>
#
# > il a deux ans de plus que mary .
# = he s two years older than mary is .
# < he s two years older than mary is . <EOS>
#
# > elle a dix huit ans au plus .
# = she is eighteen at most .
# < she is eighteen at most . <EOS>
#
# > nous sommes des prisonniers .
# = we re prisoners .
# < we re prisoners . <EOS>
#
# > tu me fais rougir .
# = you re making me blush .
# < you re amusing . <EOS>
#
# > j ai le meme age .
# = i am the same age .
# < i m the same age . <EOS>
#
# Iter: 35
# Learning Rate: 1
# Time: 0h 9m 31s
# Train Loss: 0.2050573658333649
#
# > vous etes decue n est ce pas ?
# = you re disappointed aren t you ?
# < you re disappointed aren t you ? <EOS>
#
# > tu vas te remettre .
# = you re going to be ok .
# < you re going to be ok again . <EOS>
#
# > je suis calme .
# = i am calm .
# < i m retired now . <EOS>
#
# > j ai raison .
# = i m correct .
# < i m so think . <EOS>
#
# > je suis moi meme un peu lecteur .
# = i m a bit of a reader myself .
# < i m a bit of a bit myself . <EOS>
#
# > vous etes plus intelligents que moi .
# = you re smarter than me .
# < you re smarter than me . <EOS>
#
# > nous sommes ici .
# = we are here .
# < we re here here . <EOS>
#
# > vous etes branche .
# = you re fashionable .
# < you are fashionable . <EOS>
#
# > t es une chouette gonzesse .
# = you are a good person .
# < you re a good good person . <EOS>
#
# > ils ont raison bien sur .
# = they re right of course .
# < they re right of course . <EOS>
#
# Iter: 36
# Learning Rate: 1
# Time: 0h 9m 48s
# Train Loss: 0.1920036981219895
#
# > je n abandonne pas facilement .
# = i m no quitter .
# < i m no quitter . <EOS>
#
# > ils sont trop proches .
# = they are too close .
# < they re too close . <EOS>
#
# > je sais nager .
# = i m able to swim .
# < i am able to swim tomorrow . <EOS>
#
# > il est familier de la culture japonaise .
# = he is familiar with japanese culture .
# < he is familiar with japanese japanese . <EOS>
#
# > c est vous l institutrice .
# = you re the teacher .
# < you re the teacher . <EOS>
#
# > c est vous le doyen .
# = you re the oldest .
# < you re the oldest . <EOS>
#
# > je n irai pas au cinema demain .
# = i m not going to the movies tomorrow .
# < i m not going to the movies tomorrow . <EOS>
#
# > vous cooperez .
# = you re cooperating .
# < you re hiding . <EOS>
#
# > je me rejouis que vous soyez venue .
# = i m glad you came over .
# < i m glad you came over . <EOS>
#
# > nous ne sommes pas toutes enseignantes .
# = we re not all teachers .
# < we re not all teachers . <EOS>
#
# Iter: 37
# Learning Rate: 1
# Time: 0h 10m 4s
# Train Loss: 0.1781225975772585
#
# > elles sont sorties faire les magasins .
# = they are out shopping .
# < they are out shopping people . <EOS>
#
# > je suis fascinee .
# = i m fascinated .
# < i m fascinated . <EOS>
#
# > vous etes odieux .
# = you re obnoxious .
# < you re being mine . <EOS>
#
# > tu es tres ingenieux .
# = you re very clever .
# < you re very clever . <EOS>
#
# > elles sont inutiles .
# = they re useless .
# < they re mine . <EOS>
#
# > je suis desole si je vous ai derange .
# = i m sorry if i disturbed you .
# < i m sorry if i disturbed you . <EOS>
#
# > je suis finlandais .
# = i m finnish .
# < i m an american . <EOS>
#
# > je suis rationnelle .
# = i m rational .
# < i m being rational . <EOS>
#
# > je fais preuve de bon sens .
# = i m being sensible .
# < i m in that thing thing . <EOS>
#
# > pour moi c est la fin des haricots .
# = i m at the end of my rope .
# < i m at the end of my class . <EOS>
#
# Iter: 38
# Learning Rate: 1
# Time: 0h 10m 20s
# Train Loss: 0.16640599593105027
#
# > je fais mes devoirs .
# = i m doing my homework .
# < i am doing my homework . <EOS>
#
# > ils vous attendent .
# = they re waiting for you .
# < they re waiting for you to know . <EOS>
#
# > elle est bienveillante .
# = she is good natured .
# < she is good but she is hard . <EOS>
#
# > il est aveugle par l amour .
# = he is blinded by love .
# < he s blinded by love . <EOS>
#
# > je depends de toi .
# = i m depending on you .
# < i m trying to help you . <EOS>
#
# > vous etes trop maigre .
# = you re too skinny .
# < you re too loud . <EOS>
#
# > il est dans le petrin .
# = he is in trouble now .
# < he is in trouble a park . <EOS>
#
# > pas question que je te laisse y aller .
# = i m not letting you go .
# < i m not letting you go . <EOS>
#
# > vous etes deux fois plus fortes que moi .
# = you are twice as strong as i am .
# < you are twice as strong as i am . <EOS>
#
# > ils sont nerveux .
# = they re jittery .
# < they re jittery . <EOS>
#
# Iter: 39
# Learning Rate: 1
# Time: 0h 10m 37s
# Train Loss: 0.15545785625384936
#
# > tu es disponible maintenant ?
# = you aren t busy now are you ?
# < you aren t busy now are you ? <EOS>
#
# > je suis au restaurant .
# = i m at the restaurant .
# < i m at the office . <EOS>
#
# > vous etes un drole de zozo .
# = you re a funny guy .
# < you re a funny guy . <EOS>
#
# > elles sont russes .
# = they are russian .
# < they are russian . <EOS>
#
# > vous etes de retour .
# = you re back .
# < you are back . <EOS>
#
# > nous en avons fini ici .
# = we re finished here .
# < we re done here . <EOS>
#
# > il est ici pour nous espionner .
# = he s here to spy on us .
# < he s here to spy on us . <EOS>
#
# > vous avez tous deux faux .
# = you are both in the wrong .
# < you are both in the wrong . <EOS>
#
# > ils sont en danger .
# = they re in danger .
# < they re in danger . <EOS>
#
# > elle me montra sa nouvelle voiture .
# = she showed me her new car .
# < she showed me new new car . <EOS>
#
# Iter: 40
# Learning Rate: 1
# Time: 0h 10m 53s
# Train Loss: 0.1453541777156213
#
# > nous sommes timides .
# = we re shy .
# < we re quite . <EOS>
#
# > je suis en train de changer de poste .
# = i m between jobs .
# < i m between jobs . <EOS>
#
# > c est un binoclard .
# = he s a nerd .
# < he s a tough nerd . <EOS>
#
# > il est deja parti .
# = he s already left .
# < he s already left left . <EOS>
#
# > nous nous en sortons tres bien .
# = we re doing great .
# < we re doing great . <EOS>
#
# > je suis heureux que tu aies apprecie .
# = i m glad you enjoyed it .
# < i m glad you liked it . <EOS>
#
# > j en suis sure .
# = i m sure .
# < i m sure . <EOS>
#
# > il ment mal .
# = he s a bad liar .
# < he s a bad liar . <EOS>
#
# > il souffre d un mal de dents .
# = he is suffering from toothache .
# < he is suffering from toothache . <EOS>
#
# > nous sommes consciencieuses .
# = we re conscientious .
# < we re unemployed . <EOS>
#
# Iter: 41
# Learning Rate: 1
# Time: 0h 11m 9s
# Train Loss: 0.13541653403656392
#
# > je suis de shizuoka .
# = i am from shizuoka .
# < i am from out of name . <EOS>
#
# > nous sommes de retour .
# = we re back .
# < we re back . <EOS>
#
# > elle est tranchante .
# = she is sharp .
# < she s an typist driver . <EOS>
#
# > j en ai marre de ce jeu .
# = i m sick of this game .
# < i m sick of this game . <EOS>
#
# > je suis desolee mon pere est dehors .
# = i m sorry my father is out .
# < i m sorry my father is out . <EOS>
#
# > on ne l invite pas aux fetes .
# = she s not invited to parties .
# < she s not invited to parties . <EOS>
#
# > je suis prete si tu l es .
# = i m ready if you are .
# < i m ready if you are . <EOS>
#
# > il est toujours en vie .
# = he s still alive .
# < he is always alive . <EOS>
#
# > nous sommes tous temoins .
# = we re all witnesses .
# < we re all witnesses . <EOS>
#
# > je me trouve pres de la gare .
# = i am near the station .
# < i am near the station . <EOS>
#
# Iter: 42
# Learning Rate: 1
# Time: 0h 11m 26s
# Train Loss: 0.12589591148445856
#
# > vous etes celle qui m a entraine .
# = you re the one who trained me .
# < you re the one who trained me . <EOS>
#
# > t es givre !
# = you re nuts !
# < you re so sweet . <EOS>
#
# > je suis marie .
# = i m married .
# < i m married . <EOS>
#
# > je suis enchante d etre ici .
# = i m delighted to be here .
# < i m delighted to be here . <EOS>
#
# > je suis aussi curieuse que toi .
# = i m as curious as you are .
# < i m as curious as you are . <EOS>
#
# > tu es triste .
# = you re sad .
# < you re sad . <EOS>
#
# > c est quelqu un de bien .
# = he s a good person .
# < he s a good person . <EOS>
#
# > vous etes naives .
# = you re naive .
# < you are naive . <EOS>
#
# > vous etes l elue .
# = you are the chosen one .
# < you are the one one one . <EOS>
#
# > je vous donne ce que vous voulez .
# = i m giving you what you want .
# < i m giving you what you want . <EOS>
#
# Iter: 43
# Learning Rate: 1
# Time: 0h 11m 42s
# Train Loss: 0.11855602130972728
#
# > vous etes tres elegant .
# = you re very stylish .
# < you re very very funny . <EOS>
#
# > j ai un peu sommeil .
# = i m feeling kind of sleepy .
# < i m feeling kind of sleepy . <EOS>
#
# > je suis tres fatigue par le dur labeur .
# = i am very tired from the hard work .
# < i am very tired from the hard work . <EOS>
#
# > nous nous amusons .
# = we re having fun .
# < we re getting ourselves . <EOS>
#
# > tu es celle qui m a entrainee .
# = you re the one who trained me .
# < you re the one who trained me . <EOS>
#
# > je vais attraper le bus suivant .
# = i m going to catch the next bus .
# < i m going to go next bus . <EOS>
#
# > elles ont peur de lui .
# = they re afraid of him .
# < they re afraid of him . <EOS>
#
# > le bleu vous sied superbement .
# = you are very attractive in blue .
# < you are very attractive in blue . <EOS>
#
# > tu es gentil .
# = you re kind .
# < you re kind of satisfied . <EOS>
#
# > j eprouve de la compassion .
# = i m sympathetic .
# < i m trying to fly to the river . <EOS>
#
# Iter: 44
# Learning Rate: 1
# Time: 0h 11m 58s
# Train Loss: 0.11314140290988933
#
# > c est un bon medecin .
# = he is a good doctor .
# < he is a good doctor at a doctor . <EOS>
#
# > je suis desireux de vous aider .
# = i am willing to help you .
# < i am willing to help you . <EOS>
#
# > nous sommes sideres .
# = we re stunned .
# < we re busy . <EOS>
#
# > nous sommes pareilles .
# = we re the same .
# < we re the same we . <EOS>
#
# > je ne suis pas ta fille .
# = i m not your daughter .
# < i m not your daughter . <EOS>
#
# > je n en ai pas fini avec toi .
# = i m not finished with you .
# < i m not finished with you . <EOS>
#
# > je suis desespere .
# = i m desperate .
# < i m desperate . <EOS>
#
# > vous passez a cote .
# = you re missing the point .
# < you re missing the point . <EOS>
#
# > c est une fille intelligente et independante .
# = she s a smart and independent girl .
# < she s a smart and independent girl . <EOS>
#
# > tu rougis !
# = you re blushing .
# < you are stupid . <EOS>
#
# Iter: 45
# Learning Rate: 1
# Time: 0h 12m 15s
# Train Loss: 0.1048401682054907
#
# > je songe au projet .
# = i m thinking of the plan .
# < i m thinking of the plan . <EOS>
#
# > je suis rassasie !
# = i m full .
# < i m full ! <EOS>
#
# > il lit un roman en ce moment .
# = he s reading a novel right now .
# < he s reading a novel right now . <EOS>
#
# > il est professeur d italien .
# = he s an italian teacher .
# < he s an italian italian italian . <EOS>
#
# > vous etes fort effrontes .
# = you re very forward .
# < you re very forward . <EOS>
#
# > tu es a la fois mignonne et gentille .
# = you are both pretty and kind .
# < you are both pretty and kind . <EOS>
#
# > il parle anglais couramment .
# = he is fluent in english .
# < he is fluent in english . <EOS>
#
# > je ne sais pas bien nager .
# = i m bad at swimming .
# < i am not good at swimming . <EOS>
#
# > vous etes idiots .
# = you re silly .
# < you re stupid . <EOS>
#
# > tu le fais comme il faut .
# = you re doing it right .
# < you re doing it right . <EOS>
#
# Iter: 46
# Learning Rate: 1
# Time: 0h 12m 31s
# Train Loss: 0.09973627813319157
#
# > tu n es pas contusionnee .
# = you re not bruised .
# < you re not a suspect . <EOS>
#
# > tu es grossier .
# = you re rude .
# < you re rude to teacher . <EOS>
#
# > vous etes fort occupees .
# = you re very busy .
# < you re very busy . <EOS>
#
# > je suis marie et j ai deux fils .
# = i am married and i have two sons .
# < i am married and i have two sons . <EOS>
#
# > nous sommes tous ensemble a l instant .
# = we re all together right now .
# < we re all together right now . <EOS>
#
# > je desespere de te voir !
# = i m dying to see you .
# < i m dying to see you re impatient <EOS>
#
# > je suis desolee si je vous ai derangees .
# = i m sorry if i disturbed you .
# < i m sorry if i disturbed you . <EOS>
#
# > il est trop confiant .
# = he s too trusting .
# < he s too trusting . <EOS>
#
# > c est un homme qui adore les ceremonies .
# = he is a man who loves ceremonies .
# < he is a man of loves ceremonies . <EOS>
#
# > j ai confiance .
# = i m confident .
# < i m confident . <EOS>
#
# Iter: 47
# Learning Rate: 1
# Time: 0h 12m 47s
# Train Loss: 0.09411970036649497
#
# > je ne vais pas m evanouir .
# = i m not going to pass out .
# < i m not going to get out . <EOS>
#
# > il est pionnier en ce domaine .
# = he is a pioneer in this field .
# < he is a pioneer in this field . <EOS>
#
# > ils ne vont pas aider tom .
# = they aren t going to help tom .
# < they aren t going to help tom . <EOS>
#
# > elle est en colere apres moi .
# = she is angry with me .
# < she is angry with me . <EOS>
#
# > je m amuse comme un fou .
# = i m having the time of my life .
# < i m having the time of my life . <EOS>
#
# > vous etes tous a moi .
# = you re all mine .
# < you re all mine . <EOS>
#
# > vous etes fort brave .
# = you re very brave .
# < you re very emotional . <EOS>
#
# > je suis fort .
# = i m strong .
# < i m strong too . <EOS>
#
# > ce sont de bonnes gens .
# = they are good people .
# < they are good people . <EOS>
#
# > je suis detendu .
# = i m relaxed .
# < i m a farmer . <EOS>
#
# Iter: 48
# Learning Rate: 1
# Time: 0h 13m 4s
# Train Loss: 0.08843372902814305
#
# > nous ne nous y rendons pas .
# = we re not going .
# < we re not going . <EOS>
#
# > je fais des progres .
# = i m making progress .
# < i am making progress progress . <EOS>
#
# > je me rejouis que vous vous portiez mieux .
# = i m glad you re doing better .
# < i m glad you re doing better . <EOS>
#
# > il est puissant .
# = he is powerful .
# < he s powerful . <EOS>
#
# > nous aussi nous sommes ici .
# = we re here too .
# < we re here to we here . <EOS>
#
# > tu es tres peureux .
# = you re very timid .
# < you re very very timid . <EOS>
#
# > je vais passer a la television .
# = i m going to be on tv .
# < i m going to be on tv . <EOS>
#
# > il s appuie sur une canne .
# = he s leaning on a cane .
# < he s leaning on a cane . <EOS>
#
# > nous sommes toutes en colere .
# = we re all angry .
# < we re all angry . <EOS>
#
# > ce sont des illets .
# = they re carnations .
# < they re carnations . <EOS>
#
# Iter: 49
# Learning Rate: 1
# Time: 0h 13m 20s
# Train Loss: 0.08493552934836258
#
# > c est bien .
# = i m glad to hear that .
# < she s quite satisfied . <EOS>
#
# > je suis un simple employe de bureau .
# = i m just a plain office worker .
# < i m just a plain office worker . <EOS>
#
# > tu es tres intelligent .
# = you re very intelligent .
# < you re very smart . <EOS>
#
# > je suis contente de vous voir ici .
# = i m glad to see you here .
# < i m glad to see you here . <EOS>
#
# > il n est plus celui qu il etait .
# = he is not what he used to be .
# < he is not what he used to be . <EOS>
#
# > je suis familier de ces choses .
# = i m familiar with such things .
# < i m familiar with such such things . <EOS>
#
# > nous sommes normales .
# = we re normal .
# < we re normal . <EOS>
#
# > je suis desarmee .
# = i m powerless .
# < i m quite devastated . <EOS>
#
# > je suis heureux de t avoir invite .
# = i m glad i invited you .
# < i m glad i invited you . <EOS>
#
# > tu es idiot .
# = you re silly .
# < you re very stupid . <EOS>
#
# Iter: 50
# Learning Rate: 1
# Time: 0h 13m 36s
# Train Loss: 0.07962593398829507
#
# > vous etes tres flexibles .
# = you re very flexible .
# < you are very very kind . <EOS>
#
# > j ai trop sommeil pour faire mes devoirs .
# = i m too sleepy to do my homework .
# < i m too sleepy to do my homework . <EOS>
#
# > c est un homme de foi .
# = he is a man of faith .
# < he s a man of faith . <EOS>
#
# > nous partons pour hawai ce soir .
# = we are leaving for hawaii tonight .
# < we are leaving for hawaii tonight . <EOS>
#
# > elle lui montra la photo .
# = she showed him the photo .
# < she saw him the photo . <EOS>
#
# > tu mens n est ce pas ?
# = you re lying aren t you ?
# < you re lying aren t you ? <EOS>
#
# > il n est pas dans notre groupe .
# = he s not in our group .
# < he s not in our group . <EOS>
#
# > ca va merci .
# = i m fine thank you .
# < she really much thank you . <EOS>
#
# > je me rejouis que vous compreniez .
# = i m glad that you understand .
# < i m glad you came over . <EOS>
#
# > ils sont trop proches .
# = they are too close .
# < they are too close . <EOS>
#
# Iter: 51
# Learning Rate: 1
# Time: 0h 13m 53s
# Train Loss: 0.07639401154082857
#
# > elle a arrete de parler .
# = she stopped talking .
# < she stopped talking with talking . <EOS>
#
# > nous sommes debout tot .
# = we re up early .
# < we re up to getting up early . <EOS>
#
# > elles sont juste pour vous .
# = they re just for you .
# < they re just for you . <EOS>
#
# > vous etes fort genereuse .
# = you re very generous .
# < you are very generous as a bee . <EOS>
#
# > je suis desolee de vous avoir mal compris .
# = i m sorry i misunderstood you .
# < i m sorry i misunderstood you . <EOS>
#
# > on n a plus le temps .
# = we re out of time .
# < we re out of time . <EOS>
#
# > ca ne vous reussit pas .
# = you re not good at this .
# < you re not good at this . <EOS>
#
# > elle est forte .
# = she is strong .
# < she s strong young . <EOS>
#
# > je suis a la prison .
# = i m at the prison .
# < i m at the prison . <EOS>
#
# > tu es inquiet pas vrai ?
# = you re worried aren t you ?
# < you re not a clever aren t you ? <EOS>
#
# Iter: 52
# Learning Rate: 1
# Time: 0h 14m 9s
# Train Loss: 0.07337255160223846
#
# > je ne suis jamais en colere sans raison .
# = i m never angry without reason .
# < i m never angry without reason . <EOS>
#
# > il a honte de son attitude .
# = he is ashamed of his behavior .
# < he is ashamed of his behavior . <EOS>
#
# > j ai peur de devoir partir maintenant .
# = i am afraid i must be going now .
# < i am afraid i must be going now . <EOS>
#
# > nous nous rendons au marche .
# = we are going to the market .
# < we are going to the market . <EOS>
#
# > je pars en voyage d affaire .
# = i m going on a business trip .
# < i m going on a business trip . <EOS>
#
# > je sors cet apres midi .
# = i am going out this afternoon .
# < i am going out this afternoon . <EOS>
#
# > je suis ingenue .
# = i m innocent .
# < i m at japanese side . <EOS>
#
# > je connais l auteur .
# = i am acquainted with the author .
# < i am acquainted with him . <EOS>
#
# > je ne fais pas partie de leur groupe .
# = i m not one of them .
# < i m not one of them . <EOS>
#
# > j apprends tant de toi .
# = i m learning so much from you .
# < i m learning so much much from you . <EOS>
#
# Iter: 53
# Learning Rate: 1
# Time: 0h 14m 25s
# Train Loss: 0.06947814476017247
#
# > il est certain de venir .
# = he is sure to come .
# < he is sure to come come . <EOS>
#
# > je suis occupe .
# = i am busy .
# < i m busy busy . <EOS>
#
# > c est pour vous que je suis venu .
# = you re the reason i came .
# < you re the reason i came . <EOS>
#
# > t es un bon garcon !
# = you are a good boy .
# < you a a good boy . <EOS>
#
# > vous etes plus grande que moi .
# = you re taller than i am .
# < you re taller than i am . <EOS>
#
# > vous avez parfaitement raison .
# = you are absolutely right .
# < you re absolutely right . <EOS>
#
# > tu es entete .
# = you re stubborn .
# < you re stubborn . <EOS>
#
# > j eprouve du ressentiment .
# = i m resentful .
# < i m calling from the move . <EOS>
#
# > je suis le plus jeune enfant .
# = i m the youngest in the family .
# < i m the youngest in the family . <EOS>
#
# > ils sont tres massifs .
# = they are very big .
# < they are very kind to other . <EOS>
#
# Iter: 54
# Learning Rate: 1
# Time: 0h 14m 42s
# Train Loss: 0.06772333450862046
#
# > je suis desolee .
# = i am sorry .
# < i m sorry . <EOS>
#
# > nous travaillons a l instant .
# = we re working at the moment .
# < we re working at the moment . <EOS>
#
# > nous en sommes tous d accord .
# = we re all agreed on that .
# < we re all agreed on that . <EOS>
#
# > elles sont juste pour vous .
# = they re just for you .
# < they re just for you . <EOS>
#
# > tu n es pas different .
# = you re no different .
# < you re no different . <EOS>
#
# > je t en supplie .
# = i m begging you .
# < i m begging you . <EOS>
#
# > je suis en train de discuter .
# = i m talking .
# < i m talking . <EOS>
#
# > elle a eu du mal a se lever .
# = she struggled to get up .
# < she struggled to get up . <EOS>
#
# > tu vas gagner aujourd hui .
# = you re going to win today .
# < you re going to win today . <EOS>
#
# > je ne suis pas libre tout de suite .
# = i m not available right now .
# < i m not available right now . <EOS>
#
# Iter: 55
# Learning Rate: 1
# Time: 0h 14m 58s
# Train Loss: 0.06303443776041277
#
# > il porte un nouveau manteau .
# = he s wearing a new coat .
# < he s wearing a new coat . <EOS>
#
# > je suis tres fiere de mon pere .
# = i m very proud of my father .
# < i m very proud of my father . <EOS>
#
# > il se cache dans la penderie .
# = he s hiding in the closet .
# < he s hiding in the closet . <EOS>
#
# > je suis en train de mediter .
# = i m meditating .
# < i m meditating . <EOS>
#
# > tu es si gentil !
# = you re so sweet .
# < you re so sweet . <EOS>
#
# > je suis sur de son succes .
# = i am sure of her success .
# < i am sure of her success . <EOS>
#
# > vous me genez .
# = you re embarrassing me .
# < you re embarrassing me . <EOS>
#
# > elle sembla indifferente .
# = she seemed uninterested .
# < she seemed uninterested . <EOS>
#
# > je suis un puriste .
# = i m a purist .
# < i m a social student . <EOS>
#
# > vous etes vilain .
# = you are naughty .
# < you re beautiful . <EOS>
#
# Iter: 56
# Learning Rate: 1
# Time: 0h 15m 14s
# Train Loss: 0.061972201638282674
#
# > vous n etes pas censes etre la dedans .
# = you re not supposed to be in here .
# < you re not supposed to be in here . <EOS>
#
# > je suis de meilleur humeur maintenant .
# = i m in a better mood now .
# < i m in a better mood now . <EOS>
#
# > nous sommes toutes d accord .
# = we re all in agreement .
# < we re all retired . <EOS>
#
# > vous etes tres perspicaces .
# = you re very perceptive .
# < you re very perceptive . <EOS>
#
# > il est dans sa bibliotheque .
# = he is in his library .
# < he s in his field . <EOS>
#
# > vous etes sinistre .
# = you re creepy .
# < you re surrounded . <EOS>
#
# > vous n etes pas la premiere .
# = you re not the first .
# < you re not the first . <EOS>
#
# > nous ne sommes que des enfants .
# = we re just children .
# < we re just children . <EOS>
#
# > je vais y repenser encore une fois .
# = i m going to reconsider it .
# < i m going to reconsider it . <EOS>
#
# > nous sommes en train de le changer .
# = we re changing it .
# < we re changing it . <EOS>
#
# Iter: 57
# Learning Rate: 1
# Time: 0h 15m 31s
# Train Loss: 0.05972614791531204
#
# > elle est inquiete de ta securite .
# = she s worried about your safety .
# < she s worried about your safety . <EOS>
#
# > je suis desolee de vous avoir tire dessus .
# = i m sorry i shot you .
# < i m sorry i shot you . <EOS>
#
# > nous ne sortons pas ensemble .
# = we re not on a date .
# < we re not dating . <EOS>
#
# > je songe a me rendre a l etranger .
# = i am thinking of going abroad .
# < i am thinking of going abroad . <EOS>
#
# > je suis en train de dormir .
# = i m sleeping .
# < i m remodeling . <EOS>
#
# > ils ne vont pas nous attraper .
# = they re not going to catch us .
# < they re not going to make us . <EOS>
#
# > je flippe .
# = i m freaking out .
# < i m being nervous . <EOS>
#
# > vous vous amusez n est ce pas ?
# = you re enjoying yourself aren t you ?
# < you re enjoying yourself aren t you ? <EOS>
#
# > elle le regarda droit dans les yeux .
# = she stared him in the face .
# < she stared him in the face . <EOS>
#
# > mon travail ne me plait pas .
# = i m not happy with my job .
# < i m not happy with my job . <EOS>
#
# Iter: 58
# Learning Rate: 1
# Time: 0h 15m 47s
# Train Loss: 0.05827327723074877
#
# > il a besoin d argent .
# = he is in need of money .
# < he is in need of money . <EOS>
#
# > je suis surprise .
# = i m surprised .
# < i m surprised . <EOS>
#
# > je ne vais pas citer de noms .
# = i m not going to name names .
# < i m not going to name names . <EOS>
#
# > vous etes plus grands que moi .
# = you re taller than me .
# < you re taller than i am . <EOS>
#
# > je suis fort contrarie .
# = i m very upset .
# < i m very upset . <EOS>
#
# > tu fais des manieres .
# = you re fussy .
# < you re fussy . <EOS>
#
# > c est un nouveau venu .
# = he s a newcomer .
# < he s a new newcomer . <EOS>
#
# > j essaye de nettoyer la maison .
# = i m trying to clean the house .
# < i m trying to clean the house . <EOS>
#
# > vous etes mon heroine .
# = you are my hero .
# < you are my hero hero . <EOS>
#
# > je suis egoiste .
# = i m selfish .
# < i m selfish . <EOS>
#
# Iter: 59
# Learning Rate: 1
# Time: 0h 16m 3s
# Train Loss: 0.05581231599692553
#
# > vous etes cruel .
# = you re cruel .
# < you re a traitor . <EOS>
#
# > je ne suis pas enseignant .
# = i am not a teacher .
# < i am not a teacher . <EOS>
#
# > c est une personne sympathique .
# = he is a friendly person .
# < she is a friendly person . <EOS>
#
# > on ne rajeunit pas .
# = we re not getting any younger .
# < we re not getting any younger . <EOS>
#
# > il est negligent en matiere d argent .
# = he is careless about money .
# < he is careless about money . <EOS>
#
# > nous sortons .
# = we re going out .
# < we re getting . <EOS>
#
# > nous sommes completement cool avec ca .
# = we re totally cool with that .
# < we re really cool with that . <EOS>
#
# > ils sont si droles .
# = they re so funny .
# < they re just so funny . <EOS>
#
# > elle est toujours soigneusement vetue .
# = she is always neatly dressed .
# < she is always neatly dressed . <EOS>
#
# > vous etes deprimees n est ce pas ?
# = you re depressed aren t you ?
# < you re depressed aren t you ? <EOS>

# %%
ls

# %%
from google.colab import files
files.download('testdata.orig_trim.10_vocab.20000_directions.2_layers.2_hidden.440_dropout.0.2_learningrate.1_batch.32_epochs.100.txt')

# %%
outside_sent = "ils ont tenu une réunion au café local en bas de la rue."
outside_sent = normalizeString(outside_sent)
evaluate(encoder, decoder, outside_sent, cutoff_length=10)
